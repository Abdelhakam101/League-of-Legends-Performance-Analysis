# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('League of Legends 2021 World Championship Play-In Groups Statistics - Raw Data.csv')
df
# Out:
#     Team    Player Opponent Position Champion  Kills  Deaths  Assists  \
# 0    UOL      Boss       GS      Top  Camille      4       5        3
# 1     GS     Crazy      UOL      Top     Gwen      3       1        9
# 2    UOL  Ahahacik       GS   Jungle  Trundle      2       4        5
# 3     GS    Mojito      UOL   Jungle    Talon      5       4       10
# 4    UOL    Nomanz       GS      Mid  Leblanc      1       3        4
# ..   ...       ...      ...      ...      ...    ...     ...      ...
# 215  BYG     Maoan      UOL      Mid     Ryze      4       4        2
# 216  UOL  Argonavt      BYG      Adc    Senna      1       3        9
# 217  BYG     Doggo      UOL      Adc   Draven     10       2        4
# 218  UOL    Santas      BYG  Support   Wukong      0       4        7
# 219  BYG      Kino      UOL  Support    Rakan      0       5        9
#
#      Creep Score  Gold Earned  Champion Damage Share  Kill Participation  \
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    220
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Team                   220 non-null    object
#  1   Player                 220 non-null    object
#  2   Opponent               220 non-null    object
#  3   Position               220 non-null    object
#  4   Champion               220 non-null    object
#  5   Kills                  220 non-null    int64
#  6   Deaths                 220 non-null    int64
#  7   Assists                220 non-null    int64
#  8   Creep Score            220 non-null    int64
#  9   Gold Earned            220 non-null    int64
#  10  Champion Damage Share  220 non-null    float64
#  11  Kill Participation     220 non-null    float64
#  12  Wards Placed           220 non-null    int64
#  13  Wards Destroyed        220 non-null    int64
# ...

# %%
df.describe()
# Out:
#             Kills      Deaths     Assists  Creep Score   Gold Earned  \
# count  220.000000  220.000000  220.000000   220.000000    220.000000
# mean     2.709091    2.718182    5.668182   200.340909  11008.159091
# std      2.579673    1.747179    3.888149   101.328153   3198.806207
# min      0.000000    0.000000    0.000000    14.000000   4714.000000
# 25%      1.000000    1.000000    3.000000   156.000000   8691.250000
# 50%      2.000000    3.000000    5.000000   210.000000  10454.500000
# 75%      4.000000    4.000000    8.000000   266.250000  13431.750000
# max     13.000000    7.000000   19.000000   419.000000  20546.000000
#
#        Champion Damage Share  Kill Participation  Wards Placed  \
# count             220.000000          220.000000    220.000000
# mean                0.200000            0.608273     19.454545
# std                 0.095051            0.190404     15.713553
# min                 0.040000            0.000000      3.000000
# ...

# %%
df.describe(include = 'O')
# Out:
#        Team Player Opponent Position      Champion Result
# count   220    220      220      220           220    220
# unique   10     55       10        5            67      2
# top     UOL   Boss      UOL      Top  Miss Fortune      L
# freq     25      5       25       44            18    110

# %%
df.nunique()
# Out:
# Team                      10
# Player                    55
# Opponent                  10
# Position                   5
# Champion                  67
# Kills                     12
# Deaths                     8
# Assists                   18
# Creep Score              149
# Gold Earned              215
# Champion Damage Share     39
# Kill Participation        60
# Wards Placed              50
# Wards Destroyed           24
# Ward Interactions         56
# Dragons For                5
# Dragons Against            5
# Barons For                 3
# Barons Against             3
# Result                     2
# dtype: int64

# %%
df.groupby('Team')[['Player']].nunique().reset_index()
# Out:
#   Team  Player
# 0  BYG       6
# 1   C9       6
# 2  DFM       5
# 3   GS       6
# 4  HLE       6
# 5  INF       5
# 6  LNG       5
# 7  PCE       6
# 8  RED       5
# 9  UOL       5

# %%
df.groupby(['Team','Player'])[['Kill Participation']].mean().head(12)
# Out:
#              Kill Participation
# Team Player
# BYG  Doggo               0.6880
#      Husha               0.5640
#      Kino                0.6420
#      Liang               0.5275
#      Maoan               0.5460
#      Pk                  0.3300
# C9   Blaber              0.6880
#      Bulcan              0.7700
#      Fudge               0.6720
#      Perkz               0.5920
#      Vulcan              0.7100
#      Zven                0.6040

# %%
df.groupby('Player')['Kills','Deaths','Assists'].sum().sort_values(by='Kills',ascending= False).reset_index().head(10)
# Out:
# C:\Users\abdel\AppData\Local\Temp\ipykernel_18724\2651222730.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Player')['Kills','Deaths','Assists'].sum().sort_values(by='Kills',ascending= False).reset_index().head(10)
#     Player  Kills  Deaths  Assists
# 0    Doggo     29       9       18
# 1      Ale     26       3       16
# 2  Yutapon     25       4       32
# 3     Boss     23      21       19
# 4     Zven     22       9       30
# 5     Deft     22       8       18
# 6    Perkz     22      12       27
# 7    Steal     21       7       32
# 8      Evi     19      11       31
# 9   Blaber     19      16       36

# %%
df.groupby('Player')['Kills','Deaths','Assists'].sum().sort_values(by='Deaths',ascending= False).reset_index().head(10)
# Out:
# C:\Users\abdel\AppData\Local\Temp\ipykernel_18724\2146035492.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Player')['Kills','Deaths','Assists'].sum().sort_values(by='Deaths',ascending= False).reset_index().head(10)
#        Player  Kills  Deaths  Assists
# 0        Kino      0      22       42
# 1        Boss     23      21       19
# 2       Husha     13      20       29
# 3       Maoan     11      20       22
# 4        Cody      4      19       15
# 5      Nomanz     14      18       24
# 6      Santas      3      18       28
# 7    Argonavt      7      17       33
# 8  Solidsnake      5      17       18
# 9    Ahahacik      8      17       26

# %%
df.groupby('Player')['Kills','Deaths','Assists'].sum().sort_values(by='Assists',ascending= False).reset_index().head(10)
# Out:
# C:\Users\abdel\AppData\Local\Temp\ipykernel_18724\3360748946.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Player')['Kills','Deaths','Assists'].sum().sort_values(by='Assists',ascending= False).reset_index().head(10)
#      Player  Kills  Deaths  Assists
# 0     Gaeng      4      12       54
# 1  Aladoric      0      10       43
# 2    Vulcan      5      16       43
# 3      Kino      0      22       42
# 4     Fudge     15      13       42
# 5    Iwandy      3       2       36
# 6    Blaber     19      16       36
# 7  Argonavt      7      17       33
# 8   Yutapon     25       4       32
# 9     Steal     21       7       32

# %%
df.loc[:,['Kills','Gold Earned']].corr()
# Out:
#                 Kills  Gold Earned
# Kills        1.000000     0.702605
# Gold Earned  0.702605     1.000000

# %%
plt.bar(df['Kills'], df['Gold Earned'])
plt.xlabel('Kills')
plt.ylabel('Gold Earned')
plt.title('Total Kills by Player')
plt.show()

# %%
df.plot.scatter(x='Kills', y='Gold Earned', alpha=1, title='Kills vs. Gold Earned')
plt.show()

# %%
champion_counts = df['Champion'].value_counts()
for lane in df['Position'].unique():
    champion = df[df['Position'] == lane]['Champion'].mode()[0]
    num_of_use = champion_counts[champion]
    print(f"the most used champion in {lane} lane: {champion} (used {num_of_use} times)")
# Out:
# the most used champion in Top lane: Jayce (used 9 times)
# the most used champion in Jungle lane: Xin Zhao (used 12 times)
# the most used champion in Mid lane: Sylas (used 9 times)
# the most used champion in Adc lane: Miss Fortune (used 18 times)
# the most used champion in Support lane: Leona (used 13 times)

# %%
df[df['Result'] == 'W'].groupby('Team')[['Player']].count().sort_values(by='Player',ascending = False)// 5
# Out:
#       Player
# Team
# DFM        4
# LNG        4
# C9         3
# HLE        3
# BYG        2
# GS         2
# PCE        2
# RED        1
# UOL        1

# %%
import matplotlib.pyplot as plt
winning_teams = df[df['Result'] == 'W']
win_counts_by_team = winning_teams['Team'].value_counts() // 5
plt.figure(figsize=(10, 6))
win_counts_by_team.plot(kind='bar')
plt.title('Number of Wins by Team')
plt.xlabel('Team')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45)
plt.show()

# %%
correlation_dragons_coins = df['Creep Score'].corr(df['Gold Earned'])
print("Correlation between Creep Score and Total Coins Earned:", correlation_dragons_coins)
# Out:
# Correlation between Creep Score and Total Coins Earned: 0.8659673846176412

# %%
correlation_dragons_coins = df['Creep Score'].corr(df['Gold Earned'])
plt.figure(figsize=(8, 6))
plt.scatter(df['Creep Score'], df['Gold Earned'], alpha=1)
plt.title('Scatter Plot: Creep Score vs. Total Coins Earned')
plt.xlabel('Creep Score')
plt.ylabel('Total Coins Earned')
plt.grid(True)

# Show the plot
plt.show()

# Print the correlation coefficient
print("Correlation between Creep Score and Total Coins Earned:", correlation_dragons_coins)
# Out:
# Correlation between Creep Score and Total Coins Earned: 0.8659673846176412

# %%
df.groupby('Team')[['Wards Placed', 'Wards Destroyed']].sum().sort_values(by='Wards Placed', ascending=False).head(10)
# Out:
#       Wards Placed  Wards Destroyed
# Team
# BYG            499              219
# C9             497              200
# DFM            488              252
# HLE            449              234
# INF            423              166
# UOL            401              185
# RED            395              159
# PCE            382              147
# GS             381              146
# LNG            365              207

# %%
df.groupby('Team')[['Dragons For', 'Dragons Against']].sum().sort_values(by='Dragons Against') // 5
# Out:
#       Dragons For  Dragons Against
# Team
# HLE            13                5
# LNG             9                6
# C9             15                8
# PCE             7                8
# GS              8                9
# DFM            13               10
# RED             6               10
# BYG            10               11
# INF             5               11
# UOL             6               14

# %%
df.groupby('Team')[['Barons For', 'Barons Against']].sum().sort_values(by='Barons Against') // 5
# Out:
#       Barons For  Barons Against
# Team
# LNG            3               0
# DFM            6               1
# C9             4               2
# GS             2               2
# HLE            3               2
# PCE            1               2
# RED            2               2
# INF            0               3
# BYG            2               5
# UOL            1               5
